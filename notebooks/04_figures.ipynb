# %%
import matplotlib.pyplot as plt

sparsity_weights = [0.01, 0.03, 0.05, 0.07, 0.1]
recon_values = [0.0287, 0.0748, 0.1004, 0.1238, 0.1742]  # from your sweep output
sparsity_values = [4.4173, 2.7046, 2.1735, 1.8281, 0.8965]

fig, ax1 = plt.subplots(figsize=(7, 5))

ax1.plot(sparsity_weights, recon_values, 'o-', color='tab:blue', label='Reconstruction loss')
ax1.set_xlabel('Sparsity weight (λ)')
ax1.set_ylabel('Reconstruction loss', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(sparsity_weights, sparsity_values, 's-', color='tab:red', label='Sparsity loss')
ax2.set_ylabel('Sparsity loss', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Reconstruction vs. Sparsity Tradeoff (World A)')
fig.tight_layout()
plt.savefig('../results/figures/sparsity_tradeoff.png', dpi=150)
plt.show()

# %%
seeds = [0, 1, 2, 3, 4]
max_a_A = [0.444, 0.780, 0.464, 0.604, 0.688]  # World A, corr with A
max_a_B = [0.471, 0.721, 0.524, 0.553, 0.649]  # World B, corr with A

max_b_A = [0.666, 0.496, 0.555, 0.801, 0.643]  # World A, corr with B
max_b_B = [0.699, 0.508, 0.564, 0.800, 0.628]  # World B, corr with B

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].plot(seeds, max_a_A, 'o-', label='World A', color='tab:blue')
axes[0].plot(seeds, max_a_B, 's--', label='World B', color='tab:orange')
axes[0].set_xlabel('Seed')
axes[0].set_ylabel('Max partial correlation with A')
axes[0].set_title('Best latent tracking A')
axes[0].legend()
axes[0].set_ylim(0, 1)

axes[1].plot(seeds, max_b_A, 'o-', label='World A', color='tab:blue')
axes[1].plot(seeds, max_b_B, 's--', label='World B', color='tab:orange')
axes[1].set_xlabel('Seed')
axes[1].set_ylabel('Max partial correlation with B')
axes[1].set_title('Best latent tracking B')
axes[1].legend()
axes[1].set_ylim(0, 1)

plt.suptitle('World A vs. World B: Representation Comparison Across Seeds')
plt.tight_layout()
plt.savefig('../results/figures/core_result_comparison.png', dpi=150)
plt.show()
